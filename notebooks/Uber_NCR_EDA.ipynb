# %%
import pandas as pd

# %%
import numpy as np

# %%
file_path = '/Users/abhinandho/Desktop/Uber NCR Project/data/processed/'

# %%
file_name = 'ncr_ride_clean.xlsx'

# %%
uber_df = pd.read_excel(file_path + file_name)

# %%
uber_df.head()
# Out:
#         Date      Time    Booking_ID Booking_Status   Customer_ID  \
# 0 2024-11-03  21:51:04  "CNR7933482"      Completed  "CID3275983"
# 1 2024-02-05  13:34:09  "CNR2810616"      Completed  "CID8085373"
# 2 2024-11-16  22:14:12  "CNR3864903"      Completed  "CID7568300"
# 3 2024-03-21  21:45:07  "CNR7975089"      Completed  "CID2782590"
# 4 2024-07-12  13:56:22  "CNR9380225"      Completed  "CID9804444"
#
#   Vehicle_Type Pickup_Location    Drop_Location  Avg_VTAT  Avg_CTAT  ...  \
# 0         Bike  Kanhaiya Nagar       Dwarka Mor       2.1      33.5  ...
# 1         Bike    Punjabi Bagh       Sohna Road       3.3      35.3  ...
# 2         Bike       Hauz Rani  Vishwavidyalaya       9.1      36.0  ...
# 3         Bike     Gwal Pahari      Narsinghpur       9.8      23.4  ...
# 4     Go Sedan      Badshahpur       Green Park       3.2      28.8  ...
#
#    Booking_Value Ride_Distance  Driver_Ratings Customer_Rating  \
# ...

# %%
uber_df.shape
# Out:
# (150000, 26)
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  datetime64[ns]
#  1   Time                               150000 non-null  object
#  2   Booking_ID                         150000 non-null  object
#  3   Booking_Status                     150000 non-null  object
#  4   Customer_ID                        150000 non-null  object
#  5   Vehicle_Type                       150000 non-null  object
#  6   Pickup_Location                    150000 non-null  object
#  7   Drop_Location                      150000 non-null  object
#  8   Avg_VTAT                           139500 non-null  float64
#  9   Avg_CTAT                           102000 non-null  float64
#  10  Cancelled_Rides_by_Customer        10500 non-null   float64
# ...

# %%
#total trips
total_trips = len(uber_df)

# %%
total_trips
# Out:
# 150000

# %%
#completed trips
completed_trips = (uber_df['Booking_Status'] == 'Completed').sum()

# %%
completed_trips
# Out:
# np.int64(93000)

# %%
#completion_rate
completion_rate = (completed_trips / total_trips) * 100

# %%
completion_rate
# Out:
# np.float64(62.0)

# %%
#total_revenue
total_revenue = (uber_df['Booking_Value']).sum()

# %%
total_revenue
# Out:
# np.float64(51846183.0)

# %%
#Average fare
avg_fare = total_revenue/completed_trips

# %%
avg_fare
# Out:
# np.float64(557.4858387096774)

# %%
cancelled_trips = (uber_df['Booking_Status'] != 'Completed').sum()
cancelled_trips
# Out:
# np.int64(57000)

# %%
uber_df['Booking_Status'].value_counts()
# Out:
# Booking_Status
# Completed                93000
# Cancelled by Driver      27000
# No Driver Found          10500
# Cancelled by Customer    10500
# Incomplete                9000
# Name: count, dtype: int64

# %%
cancelled_trips = total_trips - completed_trips
cancel_rate = cancelled_trips / total_trips
cancel_rate * 100
# Out:
# np.float64(38.0)

# %%
driver_cancel_rate = uber_df['Cancelled_Rides_by_Driver'].sum() / total_trips * 100
customer_cancel_rate = uber_df['Cancelled_Rides_by_Customer'].sum() / total_trips * 100

driver_cancel_rate, customer_cancel_rate
# Out:
# (np.float64(18.0), np.float64(7.000000000000001))
